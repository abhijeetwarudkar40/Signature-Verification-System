# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent

sys.path.append(str(PROJECT_ROOT))

# %%
from src.preprocessing import preprocess_image
from src.feature_extractor import extract_hog

# %%
image = preprocess_image(
    "../dataset/cedar/signatures/signatures_1/original_1_1.png"
)

features = extract_hog(image)

print(image.shape)

print(features.shape)
# Out:
# (100, 200)
# (9504,)

# %%
import matplotlib.pyplot as plt
import cv2
sample = "../dataset/cedar/signatures/signatures_1/original_1_1.png"

processed = preprocess_image(sample)

fig, ax = plt.subplots(1,2, figsize=(10,4))

ax[0].imshow(cv2.imread(sample, cv2.IMREAD_GRAYSCALE), cmap="gray")
ax[0].set_title("Original")

ax[1].imshow(processed, cmap="gray")
ax[1].set_title("Processed")

plt.show()
